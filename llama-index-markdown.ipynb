# %% [markdown]
# #  Markdown 知识库索引

# %%
<a href="https://colab.research.google.com/github/esonwong/learning-python/blob/main/llama-index-markdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 安装依赖

# %%
 # !pip install llama_index

# %% [markdown]
# ## 引入模块

# %%
from pathlib import Path
from llama_index import download_loader

# %% [markdown]
# ## 加载数据

# %%
arkdownReader = download_loader("MarkdownReader")

loader = MarkdownReader()
documents = loader.load_data(file=Path('./data/QA.md'))
